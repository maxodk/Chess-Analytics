# %%
import pickle
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)


import columns

# read train data
ds = pd.read_csv("C:/Users/maxim/Chess/data/new_input.csv")
print('new data size', ds.shape)

categorical_columns = ds.select_dtypes(include=['object','bool']).columns

map_dicts = dict()
for column in categorical_columns:
    ds[column] = ds[column].astype('category')
    map_dicts[column] = dict(zip(ds[column], ds[column].cat.codes))
    ds[column] = ds[column].cat.codes


# Define target and features columns
X = ds[columns.X_columns]

# load the model and predict
rf = pickle.load(open('C:/Users/maxim/Chess/models/finalized_model.sav', 'rb'))

y_pred = rf.predict(X)
y_pred_rounded = np.round(rf.predict(X))

ds['winner_pred'] = rf.predict(X)
ds['winner_pred_rounded'] = np.round(rf.predict(X))
ds.to_csv('C:/Users/maxim/Chess/data/prediction_results.csv', index=False)
ds.head()
# Out:
# new data size (2006, 16)
#      id  rated    created_at  last_move_at  turns  victory_status  winner  \
# 0   461      1  1.504113e+12  1.504113e+12     61               3       2
# 1   382      1  1.454940e+12  1.454940e+12     86               1       0
# 2  1230      1  1.466630e+12  1.466631e+12     27               3       0
# 3   488      1  1.503159e+12  1.503160e+12     79               3       2
# 4  1531      1  1.504180e+12  1.504181e+12     37               3       2
#
#    increment_code  white_id  white_rating  black_id  black_rating  moves  \
# 0               7       457          1919      1216          1798    632
# 1               7       389          1195       234          1123   1663
# 2              12      1010          1867       648          1932    966
# 3               7      1492          1823      1235          1770    318
# 4               7      1141          1371       544          1193   1714
#
# ...
